# %% [markdown]
# Sentiment Analysis on Amazon Product Reviews using NLP

# %%
# Import Libraries
import pandas as pd
import numpy as np
import re

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# %%
# upoad Dataset
from google.colab import files
files.upload()

# %%
# load Dataset
df = pd.read_csv("cleaned_reviews.csv")
df.head()
# Out:
#     ProductId  Score                                               Text  \
# 0  B001E4KFG0      5  I have bought several of the Vitality canned d...
# 1  B00813GRG4      1  "Product arrived labeled as Jumbo Salted Peanu...
# 2  B000UA0QIQ      2  If you are looking for the secret ingredient i...
# 3  B000E7L2R4      5  Right now I'm mostly just sprouting this so my...
# 4  B00171APVA      5  This is a very healthy dog food. Good for thei...
#
#   sentiment
# 0  Positive
# 1  Negative
# 2  Negative
# 3  Positive
# 4  Positive

# %%
# Data Preprocessing
def clean_text(text):
    text = re.sub(r'[^a-zA-Z]', ' ', text)   # remove symbols
    text = text.lower()                     # lowercase
    return text

df['clean_text'] = df['Text'].apply(clean_text)

# %%
# Feature Selection
X = df['clean_text']   # input
y = df['sentiment']    # output

# %%
# Convert Text → Numbers (TF-IDF)
vectorizer = TfidfVectorizer(stop_words='english', max_features=5000)
X = vectorizer.fit_transform(X)

# %%
# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2
)

# %%
# Model Implementation
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Prediction
y_pred = model.predict(X_test)

# %%
# Evaluation
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8422649140546006
#               precision    recall  f1-score   support
#
#     Negative       0.95      0.21      0.34       194
#     Positive       0.84      1.00      0.91       795
#
#     accuracy                           0.84       989
#    macro avg       0.89      0.60      0.62       989
# weighted avg       0.86      0.84      0.80       989
